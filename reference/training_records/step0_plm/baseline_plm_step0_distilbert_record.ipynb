# %% [markdown]
# # Step 0 PLM training record — distilbert-base-uncased
#
# This notebook documents the **archived** Step 0 run (campaign JSON + zip). It was generated on 2026-09-26 09:41 UTC from `reference/artifacts/baseline_plm_distilbert_base_uncased_campaign.json`.
#
# **Colab proof:** if you still have the session, export **File → Download → .ipynb** to `reference/training_records/step0_plm/colab/` and commit alongside this file.
#
# **Template used:** `notebooks/baseline_plm_campaign.ipynb`

# %%
# !./run_baseline_campaign.sh --backbone distilbert-base-uncased --epochs 4 --batch-size 16 --lr 5e-5 --early-stopping-patience 0
# Out:
# [Recorded run — see campaign JSON]
# backbone: distilbert-base-uncased
# protocol: {"batch_size": 16, "early_stopping_patience": 0, "epochs": 4, "lr": 5e-05, "max_length": 128}
#
# seed 42: best_val_f1_macro=0.489684 test_f1_macro=0.490805 epochs=4
# seed 123: best_val_f1_macro=0.489179 test_f1_macro=0.487431 epochs=4
# seed 456: best_val_f1_macro=0.493036 test_f1_macro=0.479898 epochs=4
#
# f1_micro: 0.581949 ± 0.001175
# f1_macro: 0.486045 ± 0.004559
# exact_match: 0.472023 ± 0.001893
# map: 0.505683 ± 0.000223

# %%
artifact_zip = 'reference/artifacts/baseline_plm_distilbert_step0.zip'
campaign_path = 'reference/artifacts/baseline_plm_distilbert_base_uncased_campaign.json'
print(artifact_zip, campaign_path)
# Out:
# reference/artifacts/baseline_plm_distilbert_step0.zip
# reference/artifacts/baseline_plm_distilbert_base_uncased_campaign.json
