# %% [markdown]
# # Step 0 PLM training record — roberta-base
#
# This notebook documents the **archived** Step 0 run (campaign JSON + zip). It was generated on 2026-09-26 09:41 UTC from `reference/artifacts/baseline_plm_roberta_base_campaign.json`.
#
# **Colab proof:** if you still have the session, export **File → Download → .ipynb** to `reference/training_records/step0_plm/colab/` and commit alongside this file.
#
# **Template used:** `notebooks/baseline_plm_campaign.ipynb`

# %%
# !./run_baseline_campaign.sh --backbone roberta-base --epochs 4 --batch-size 16 --lr 5e-5 --early-stopping-patience 0
# Out:
# [Recorded run — see campaign JSON]
# backbone: roberta-base
# protocol: {"batch_size": 16, "early_stopping_patience": 0, "epochs": 4, "lr": 5e-05, "max_length": 128}
#
# seed 42: best_val_f1_macro=0.490857 test_f1_macro=0.493572 epochs=4
# seed 123: best_val_f1_macro=0.492555 test_f1_macro=0.485639 epochs=4
# seed 456: best_val_f1_macro=0.480087 test_f1_macro=0.482202 epochs=4
#
# f1_micro: 0.585865 ± 0.002701
# f1_macro: 0.487138 ± 0.004761
# exact_match: 0.472883 ± 0.001869
# map: 0.512527 ± 0.001749

# %%
artifact_zip = 'reference/artifacts/baseline_plm_roberta_step0.zip'
campaign_path = 'reference/artifacts/baseline_plm_roberta_base_campaign.json'
print(artifact_zip, campaign_path)
# Out:
# reference/artifacts/baseline_plm_roberta_step0.zip
# reference/artifacts/baseline_plm_roberta_base_campaign.json
